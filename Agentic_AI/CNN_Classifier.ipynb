# %% [markdown]
# ## Data
# ### Training data
# ### Testing Data
#
# ## Notebook
# ### - Image classifier
#
# ## SRC
# ### -

# %%
#Importing Libraries 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns 
from tensorflow import keras

# %%
df = pd.read_csv("")

# %% [markdown]
# ### Data Overview

# %% [markdown]
# df.shape
# df.info()
# df.describe()

# %% [markdown]
# ### pre processing compiler

# %%
img_size = 128
batch_size=32
train_design = ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.2,
    rotation_range = 20,
    zoom_range = 0.2,
    horizontal_flip = True
)

# %%
train_data = train_design.flow_from_directory(
    dataset ,
    target_size , 
    batch_size ,
    class_mode ='binary',
    subset = 'training '
)

# %%
val_data = train_design.flow_from_directory(
    dataset ,
    target_size , 
    batch_size ,
    class_mode ='binary',
    subset = 'validation '
)
